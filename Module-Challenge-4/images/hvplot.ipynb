# %%
import numpy as np
import pandas as pd
import panel as pn

df = pd.DataFrame(np.concatenate(
    [np.random.randint(0, 10, 100), np.random.randint(10, 100, 10), np.random.randint(0, 10, 100)]
))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[90:120].plot()
# Out:
# <AxesSubplot:>

# %%
import hvplot.pandas


df.hvplot()
# Out:
# :Curve   [index]   (0)
